# %%
"""
pacfile.py -- Defines a PACFile class to handle reading and writing audio
data to an audio file holding data compressed using an MDCT-based perceptual audio
coding algorithm.  The MDCT lines of each audio channel are grouped into bands,
each sharing a single scaleFactor and bit allocation that are used to block-
floating point quantize those lines.  This class is a subclass of AudioFile.

-----------------------------------------------------------------------
© 2009 Marina Bosi & Richard E. Goldberg -- All rights reserved
-----------------------------------------------------------------------

See the documentation of the AudioFile class for general use of the AudioFile
class.

Notes on reading and decoding PAC files:

    The OpenFileForReading() function returns a CodedParams object containing:

        nChannels = the number of audio channels
        sampleRate = the sample rate of the audio samples
        numSamples = the total number of samples in the file for each channel
        nMDCTLines = half the MDCT block size (block switching not supported)
        nSamplesPerBlock = MDCTLines (but a name that PCM files look for)
        nScaleBits = the number of bits storing scale factors
        nMantSizeBits = the number of bits storing mantissa bit allocations
        sfBands = a ScaleFactorBands object
        overlapAndAdd = decoded data from the prior block (initially all zeros)

    The returned ScaleFactorBands object, sfBands, contains an allocation of
    the MDCT lines into groups that share a single scale factor and mantissa bit
    allocation.  sfBands has the following attributes available:

        nBands = the total number of scale factor bands
        nLines[iBand] = the number of MDCT lines in scale factor band iBand
        lowerLine[iBand] = the first MDCT line in scale factor band iBand
        upperLine[iBand] = the last MDCT line in scale factor band iBand


Notes on encoding and writing PAC files:

    When writing to a PACFile the CodingParams object passed to OpenForWriting()
    should have the following attributes set:

        nChannels = the number of audio channels
        sampleRate = the sample rate of the audio samples
        numSamples = the total number of samples in the file for each channel
        nMDCTLines = half the MDCT block size (format does not support block switching)
        nSamplesPerBlock = MDCTLines (but a name that PCM files look for)
        nScaleBits = the number of bits storing scale factors
        nMantSizeBits = the number of bits storing mantissa bit allocations
        targetBitsPerSample = the target encoding bit rate in units of bits per sample

    The first three attributes (nChannels, sampleRate, and numSamples) are
    typically added by the original data source (e.g. a PCMFile object) but
    numSamples may need to be extended to account for the MDCT coding delay of
    nMDCTLines and any zero-padding done in the final data block

    OpenForWriting() will add the following attributes to be used during the encoding
    process carried out in WriteDataBlock():

        sfBands = a ScaleFactorBands object
        priorBlock = the prior block of audio data (initially all zeros)

    The passed ScaleFactorBands object, sfBands, contains an allocation of
    the MDCT lines into groups that share a single scale factor and mantissa bit
    allocation.  sfBands has the following attributes available:

        nBands = the total number of scale factor bands
        nLines[iBand] = the number of MDCT lines in scale factor band iBand
        lowerLine[iBand] = the first MDCT line in scale factor band iBand
        upperLine[iBand] = the last MDCT line in scale factor band iBand

Description of the PAC File Format:

    Header:

        tag                 4 byte file tag equal to "PAC "
        sampleRate          little-endian unsigned long ("<L" format in struct)
        nChannels           little-endian unsigned short("<H" format in struct)
        numSamples          little-endian unsigned long ("<L" format in struct)
        nMDCTLines          little-endian unsigned long ("<L" format in struct)
        nScaleBits          little-endian unsigned short("<H" format in struct)
        nMantSizeBits       little-endian unsigned short("<H" format in struct)
        nSFBands            little-endian unsigned long ("<L" format in struct)
        for iBand in range(nSFBands):
            nLines[iBand]   little-endian unsigned short("<H" format in struct)

    Each Data Block:  (reads data blocks until end of file hit)

        for iCh in range(nChannels):
            nBytes          little-endian unsigned long ("<L" format in struct)
            as bits packed into an array of nBytes bytes:
                overallScale[iCh]                       nScaleBits bits
                for iBand in range(nSFBands):
                    scaleFactor[iCh][iBand]             nScaleBits bits
                    bitAlloc[iCh][iBand]                nMantSizeBits bits
                    if bitAlloc[iCh][iBand]:
                        for m in nLines[iBand]:
                            mantissa[iCh][iBand][m]     bitAlloc[iCh][iBand]+1 bits
                <extra custom data bits as long as space is included in nBytes>

"""

from audiofile import * # base class
from bitpack import *  # class for packing data into an array of bytes where each item's number of bits is specified
import codec    # module where the actual PAC coding functions reside(this module only specifies the PAC file format)
from psychoac import ScaleFactorBands, AssignMDCTLinesFromFreqLimits  # defines the grouping of MDCT lines into scale factor bands

import numpy as np  # to allow conversion of data blocks to numpy's array object
MAX16BITS = 32767


class PACFile(AudioFile):
    """
    Handlers for a perceptually coded audio file I am encoding/decoding
    """

    # a file tag to recognize PAC coded files
    tag=b'PAC '

    def ReadFileHeader(self):
        """
        Reads the PAC file header from a just-opened PAC file and uses it to set
        object attributes.  File pointer ends at start of data portion.
        """
        # check file header tag to make sure it is the right kind of file
        tag=self.fp.read(4)
        if tag!=self.tag: raise RuntimeError("Tried to read a non-PAC file into a PACFile object")
        # use struct.unpack() to load up all the header data
        (sampleRate, nChannels, numSamples, nMDCTLines, nScaleBits, nMantSizeBits) \
                 = unpack('<LHLLHH',self.fp.read(calcsize('<LHLLHH')))
        nBands = unpack('<L',self.fp.read(calcsize('<L')))[0]
        nLines=  unpack('<'+str(nBands)+'H',self.fp.read(calcsize('<'+str(nBands)+'H')))
        sfBands=ScaleFactorBands(nLines)
        # load up a CodingParams object with the header data
        myParams=CodingParams()
        myParams.sampleRate = sampleRate
        myParams.nChannels = nChannels
        myParams.numSamples = numSamples
        myParams.nMDCTLines = myParams.nSamplesPerBlock = nMDCTLines
        myParams.nScaleBits = nScaleBits
        myParams.nMantSizeBits = nMantSizeBits
        # add in scale factor band information
        myParams.sfBands =sfBands
        # start w/o all zeroes as data from prior block to overlap-and-add for output
        overlapAndAdd = []
        for iCh in range(nChannels): overlapAndAdd.append( np.zeros(nMDCTLines, dtype=np.float64) )
        myParams.overlapAndAdd=overlapAndAdd
        return myParams


    def ReadDataBlock(self, codingParams):
        """
        Reads a block of coded data from a PACFile object that has already
        executed OpenForReading() and returns those samples as reconstituted
        signed-fraction data
        """
        # loop over channels (whose coded data are stored separately) and read in each data block
        data=[]
        for iCh in range(codingParams.nChannels):
            data.append(np.array([],dtype=np.float64))  # add location for this channel's data
            # read in string containing the number of bytes of data for this channel (but check if at end of file!)
            s=self.fp.read(calcsize("<L"))  # will be empty if at end of file
            if not s:
                # hit last block, see if final overlap and add needs returning, else return nothing
                if codingParams.overlapAndAdd:
                    overlapAndAdd=codingParams.overlapAndAdd
                    codingParams.overlapAndAdd=0  # setting it to zero so next pass will just return
                    return overlapAndAdd
                else:
                    return
            # not at end of file, get nBytes from the string we just read
            nBytes = unpack("<L",s)[0] # read it as a little-endian unsigned long
            # read the nBytes of data into a PackedBits object to unpack
            pb = PackedBits()
            pb.SetPackedData( self.fp.read(nBytes) ) # PackedBits function SetPackedData() converts strings to internally-held array of bytes
            if pb.nBytes < nBytes:  raise "Only read a partial block of coded PACFile data"

            # extract the data from the PackedBits object
            overallScaleFactor = pb.ReadBits(codingParams.nScaleBits)  # overall scale factor
            scaleFactor=[]
            bitAlloc=[]
            mantissa=np.zeros(codingParams.nMDCTLines,np.int32)  # start w/ all mantissas zero
            for iBand in range(codingParams.sfBands.nBands): # loop over each scale factor band to pack its data
                ba = pb.ReadBits(codingParams.nMantSizeBits)
                if ba: ba+=1  # no bit allocation of 1 so ba of 2 and up stored as one less
                bitAlloc.append(ba)  # bit allocation for this band
                scaleFactor.append(pb.ReadBits(codingParams.nScaleBits))  # scale factor for this band
                if bitAlloc[iBand]:
                    # if bits allocated, extract those mantissas and put in correct location in matnissa array
                    m=np.empty(codingParams.sfBands.nLines[iBand],np.int32)
                    for j in range(codingParams.sfBands.nLines[iBand]):
                        m[j]=pb.ReadBits(bitAlloc[iBand])     # mantissas for this band (if bit allocation non-zero) and bit alloc <>1 so encoded as 1 lower than actual allocation
                    mantissa[codingParams.sfBands.lowerLine[iBand]:(codingParams.sfBands.upperLine[iBand]+1)] = m
            # done unpacking data (end loop over scale factor bands)

            # CUSTOM DATA:
            # < now can unpack any custom data passed in the nBytes of data >

            # (DECODE HERE) decode the unpacked data for this channel, overlap-and-add first half, and append it to the data array (saving other half for next overlap-and-add)
            decodedData = self.Decode(scaleFactor,bitAlloc,mantissa, overallScaleFactor,codingParams)
            data[iCh] = np.concatenate( (data[iCh],np.add(codingParams.overlapAndAdd[iCh],decodedData[:codingParams.nMDCTLines]) ) )  # data[iCh] is overlap-and-added data
            codingParams.overlapAndAdd[iCh] = decodedData[codingParams.nMDCTLines:]  # save other half for next pass

        # end loop over channels, return signed-fraction samples for this block
        return data


    def WriteFileHeader(self,codingParams):
        """
        Writes the PAC file header for a just-opened PAC file and uses codingParams
        attributes for the header data.  File pointer ends at start of data portion.
        """
        # write a header tag
        self.fp.write(self.tag)
        # make sure that the number of samples in the file is a multiple of the
        # number of MDCT half-blocksize, otherwise zero pad as needed
        if not codingParams.numSamples%codingParams.nMDCTLines:
            codingParams.numSamples += (codingParams.nMDCTLines
                        - codingParams.numSamples%codingParams.nMDCTLines) # zero padding for partial final PCM block
        # also add in the delay block for the second pass w/ the last half-block
        codingParams.numSamples+= codingParams.nMDCTLines  # due to the delay in processing the first samples on both sides of the MDCT block
        # write the coded file attributes
        self.fp.write(pack('<LHLLHH',
            codingParams.sampleRate, codingParams.nChannels,
            codingParams.numSamples, codingParams.nMDCTLines,
            codingParams.nScaleBits, codingParams.nMantSizeBits  ))
        # create a ScaleFactorBand object to be used by the encoding process and write its info to header
        sfBands=ScaleFactorBands( AssignMDCTLinesFromFreqLimits(codingParams.nMDCTLines,
                                                                codingParams.sampleRate)
                                )
        codingParams.sfBands=sfBands
        self.fp.write(pack('<L',sfBands.nBands))
        self.fp.write(pack('<'+str(sfBands.nBands)+'H',*(sfBands.nLines.tolist()) ))
        # start w/o all zeroes as prior block of unencoded data for other half of MDCT block
        priorBlock = []
        for iCh in range(codingParams.nChannels):
            priorBlock.append(np.zeros(codingParams.nMDCTLines,dtype=np.float64) )
        codingParams.priorBlock = priorBlock
        return


    def WriteDataBlock(self,data, codingParams):
        """
        Writes a block of signed-fraction data to a PACFile object that has
        already executed OpenForWriting()"""

        # combine this block of multi-channel data w/ the prior block's to prepare for MDCTs twice as long
        fullBlockData=[]
        for iCh in range(codingParams.nChannels):
            fullBlockData.append( np.concatenate( ( codingParams.priorBlock[iCh], data[iCh]) ) )
        codingParams.priorBlock = data  # current pass's data is next pass's prior block data

        # (ENCODE HERE) Encode the full block of multi=channel data
        (scaleFactor,bitAlloc,mantissa, overallScaleFactor, codingParams.bitReservoir) = self.Encode(fullBlockData,codingParams)  # returns a tuple with all the block-specific info not in the file header
        
        # for each channel, write the data to the output file
        for iCh in range(codingParams.nChannels):

            # determine the size of this channel's data block and write it to the output file
            nBytes =codingParams.nScaleBits  # bits for overall scale factor
            for iBand in range(codingParams.sfBands.nBands): # loop over each scale factor band to get its bits
                nBytes += codingParams.nMantSizeBits+codingParams.nScaleBits    # mantissa bit allocation and scale factor for that sf band
                if bitAlloc[iCh][iBand]:
                    # if non-zero bit allocation for this band, add in bits for scale factor and each mantissa (0 bits means zero)
                    nBytes += bitAlloc[iCh][iBand]*codingParams.sfBands.nLines[iBand]  # no bit alloc = 1 so actuall alloc is one higher
            # end computing bits needed for this channel's data

            # CUSTOM DATA:
            # < now can add space for custom data, if desired>

            # now convert the bits to bytes (w/ extra one if spillover beyond byte boundary)
            if nBytes%BYTESIZE==0:  nBytes //= BYTESIZE
            else: nBytes = nBytes//BYTESIZE + 1
            self.fp.write(pack("<L",int(nBytes))) # stores size as a little-endian unsigned long

            # create a PackedBits object to hold the nBytes of data for this channel/block of coded data
            pb = PackedBits()
            pb.Size(nBytes)

            # now pack the nBytes of data into the PackedBits object
            pb.WriteBits(overallScaleFactor[iCh],codingParams.nScaleBits)  # overall scale factor
            iMant=0  # index offset in mantissa array (because mantissas w/ zero bits are omitted)
            for iBand in range(codingParams.sfBands.nBands): # loop over each scale factor band to pack its data
                ba = bitAlloc[iCh][iBand]
                if ba: ba-=1  # if non-zero, store as one less (since no bit allocation of 1 bits/mantissa)
                pb.WriteBits(ba,codingParams.nMantSizeBits)  # bit allocation for this band (written as one less if non-zero)
                pb.WriteBits(scaleFactor[iCh][iBand],codingParams.nScaleBits)  # scale factor for this band (if bit allocation non-zero)
                if bitAlloc[iCh][iBand]:
                    for j in range(codingParams.sfBands.nLines[iBand]):
                        pb.WriteBits(mantissa[iCh][iMant+j],bitAlloc[iCh][iBand])     # mantissas for this band (if bit allocation non-zero) and bit alloc <>1 so is 1 higher than the number
                    iMant += codingParams.sfBands.nLines[iBand]  # add to mantissa offset if we passed mantissas for this band
            # done packing (end loop over scale factor bands)

            # CUSTOM DATA:
            # < now can add in custom data if space allocated in nBytes above>

            # finally, write the data in this channel's PackedBits object to the output file
            self.fp.write(pb.GetPackedData())
        # end loop over channels, done writing coded data for all channels
        return codingParams.bitReservoir

    def Close(self,codingParams):
        """
        Flushes the last data block through the encoding process (if encoding)
        and closes the audio file
        """
        # determine if encoding or encoding and, if encoding, do last block
        if self.fp.mode == "wb":  # we are writing to the PACFile, must be encode
            # we are writing the coded file -- pass a block of zeros to move last data block to other side of MDCT block
            data = [ np.zeros(codingParams.nMDCTLines,dtype=np.float),
                     np.zeros(codingParams.nMDCTLines,dtype=np.float) ]
            self.WriteDataBlock(data, codingParams)
        self.fp.close()


    def Encode(self,data,codingParams):
        """
        Encodes multichannel audio data and returns a tuple containing
        the scale factors, mantissa bit allocations, quantized mantissas,
        and the overall scale factor for each channel.
        """
        #Passes encoding logic to the Encode function defined in the codec module
        return codec.Encode(data,codingParams)

    def Decode(self,scaleFactor,bitAlloc,mantissa, overallScaleFactor,codingParams):
        """
        Decodes a single audio channel of data based on the values of its scale factors,
        bit allocations, quantized mantissas, and overall scale factor.
        """
        #Passes decoding logic to the Decode function defined in the codec module
        return codec.Decode(scaleFactor,bitAlloc,mantissa, overallScaleFactor,codingParams)


#-----------------------------------------------------------------------------

# Testing the full PAC coder (needs a file called "input.wav" in the code directory)
if __name__=="__main__":
    
    filenames = ["castanet"]#["castanet", "glockenspiel", "harpsichord", "spfe", "spmg"]  

    for this_file in filenames:
 
        print( "\nTesting the PAC coder (input.wav -> coded.pac -> output.wav):")
        import time
        from pcmfile import * # to get access to WAV file handling
        elapsed = time.time()

        for Direction in ("Encode", "Decode"):
    #    for Direction in ("Decode"):

            # create the audio file objects
            if Direction == "Encode":
                print( "\n\tEncoding input PCM file...",)
                inFile= PCMFile(this_file + ".wav")
                outFile = PACFile("coded.pac")
            else: # "Decode"
                print( "\n\tDecoding coded PAC file...",)
                inFile = PACFile("coded.pac")
                outFile= PCMFile(this_file + "_out.wav")
            # only difference is file names and type of AudioFile object

            # open input file
            codingParams=inFile.OpenForReading()  # (includes reading header)

            # pass parameters to the output file
            if Direction == "Encode":
                # set additional parameters that are needed for PAC file
                # (beyond those set by the PCM file on open)
                codingParams.nMDCTLines = 512 #1024
                codingParams.nScaleBits = 3
                codingParams.nMantSizeBits = 5
                codingParams.targetBitsPerSample = 2.9 #(2.9 -> FOR 128 kb/s, 4.35 -> FOR 192 kb/s) 
                
                # initialize bit reservoir
                codingParams.bitReservoir = 0; 
                
                print("nMDCTLines = ", codingParams.nMDCTLines)
                print("nScaleBits = ", codingParams.nScaleBits)
                print("nMantSizeBits = ", codingParams.nMantSizeBits)
                print("targetBitsSample = ", codingParams.targetBitsPerSample)
                
                # tell the PCM file how large the block size is
                codingParams.nSamplesPerBlock = codingParams.nMDCTLines
                print(codingParams.nSamplesPerBlock)
            else: # "Decode"
                # set PCM parameters (the rest is same as set by PAC file on open)
                codingParams.bitsPerSample = 16
                codingParams.bitReservoir = 0
            # only difference is in setting up the output file parameters


            # open the output file
            outFile.OpenForWriting(codingParams) # (includes writing header)

            # Read the input file and pass its data to the output file to be written
            while True:
                data=inFile.ReadDataBlock(codingParams)
                if not data: break  # we hit the end of the input file
                codingParams.bitReservoir = outFile.WriteDataBlock(data,codingParams)
#                 print("codingParams.bitReservoir", codingParams.bitReservoir)
#                 print(" --------- ")
                print( ".",end="")  # just to signal how far we've gotten to user
            # end loop over reading/writing the blocks

            # close the files
            inFile.Close(codingParams)
            outFile.Close(codingParams)
        # end of loop over Encode/Decode

        elapsed = time.time()-elapsed
        print( "\nDone with Encode/Decode test\n")
        print( elapsed ," seconds elapsed")
# Out:
# Testing the PAC coder (input.wav -> coded.pac -> output.wav):
#
# 	Encoding input PCM file...
# nMDCTLines =  512
# nScaleBits =  3
# nMantSizeBits =  5
# targetBitsSample =  2.9
# 512
# bits used 1361
# bit budget - after 1.7999999999999545
# bits used 1364
# bit budget - after 0.599999999999909
#  ---------
# .bits used 1363
# bit budget - after 0.3999999999998636
# bits used 1362
# bit budget - after 1.199999999999818
#  ---------
# .bits used 1362
# bit budget - after 1.9999999999997726
# bits used 1363
# bit budget - after 1.7999999999997272
#  ---------
# .bits used 1364
# bit budget - after 0.5999999999996817
# bits used 1362
# bit budget - after 1.3999999999996362
#  ---------
# .bits used 1363
# bit budget - after 1.1999999999995907
# bits used 1362
# bit budget - after 1.9999999999995453
#  ---------
# .bits used 1363
# bit budget - after 1.7999999999994998
# bits used 1363
# bit budget - after 1.5999999999994543
#  ---------
# .bits used 1364
# bit budget - after 0.39999999999940883
# bits used 1362
# bit budget - after 1.1999999999993634
#  ---------
# .bits used 1362
# bit budget - after 1.9999999999993179
# bits used 1364
# bit budget - after 0.7999999999992724
#  ---------
# .bits used 1362
# bit budget - after 1.599999999999227
# bits used 1283
# bit budget - after 0.39999999999918145
#  ---------
# .bits used 1363
# bit budget - after 0.19999999999913598
# bits used 1361
# bit budget - after 1.9999999999990905
#  ---------
# .bits used 1364
# bit budget - after 0.799999999999045
# bits used 1362
# bit budget - after 1.5999999999989996
#  ---------
# .bits used 1363
# bit budget - after 1.399999999998954
# bits used 1282
# bit budget - after 1.1999999999989086
#  ---------
# .bits used 1363
# bit budget - after 0.9999999999988631
# bits used 1362
# bit budget - after 1.7999999999988177
#  ---------
# .bits used 1364
# bit budget - after 0.5999999999987722
# bits used 1363
# bit budget - after 0.3999999999987267
#  ---------
# .bits used 1363
# bit budget - after 0.19999999999868123
# bits used 1362
# bit budget - after 0.9999999999986358
#  ---------
# .bits used 1362
# bit budget - after 1.7999999999985903
# bits used 1363
# bit budget - after 1.5999999999985448
#  ---------
# .bits used 1363
# bit budget - after 1.3999999999984993
# bits used 1363
# bit budget - after 1.1999999999984539
#  ---------
# .bits used 1363
# bit budget - after 0.9999999999984084
# bits used 1362
# bit budget - after 1.799999999998363
#  ---------
# .bits used 1364
# bit budget - after 0.5999999999983174
# bits used 1282
# bit budget - after 0.39999999999827196
#  ---------
# .bits used 1362
# bit budget - after 1.1999999999982265
# bits used 1363
# bit budget - after 0.999999999998181
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999981355
#  ---------
# .bits used 1363
# bit budget - after 1.3999999999980446
# bits used 1364
# bit budget - after 0.1999999999979991
#  ---------
# .bits used 1361
# bit budget - after 1.9999999999979536
# bits used 1283
# bit budget - after 0.7999999999979082
#  ---------
# .bits used 1362
# bit budget - after 1.5999999999978627
# bits used 1363
# bit budget - after 1.3999999999978172
#  ---------
# .bits used 1363
# bit budget - after 1.1999999999977717
# bits used 1363
# bit budget - after 0.9999999999977263
#  ---------
# .bits used 1363
# bit budget - after 0.7999999999976808
# bits used 1363
# bit budget - after 0.5999999999976353
#  ---------
# .bits used 1363
# bit budget - after 0.39999999999758984
# bits used 1363
# bit budget - after 0.19999999999754436
#  ---------
# .bits used 1361
# bit budget - after 1.999999999997499
# bits used 1364
# bit budget - after 0.7999999999974534
#  ---------
# .bits used 1363
# bit budget - after 0.5999999999974079
# bits used 1362
# bit budget - after 1.3999999999973625
#  ---------
# .bits used 1363
# bit budget - after 1.199999999997317
# bits used 1362
# bit budget - after 1.9999999999972715
#  ---------
# .bits used 1364
# bit budget - after 0.799999999997226
# bits used 1363
# bit budget - after 0.5999999999971806
#  ---------
# .bits used 1282
# bit budget - after 0.3999999999971351
# bits used 1363
# bit budget - after 0.19999999999708962
#  ---------
# .bits used 1361
# bit budget - after 1.9999999999970441
# bits used 1282
# bit budget - after 1.7999999999969987
#  ---------
# .bits used 1282
# bit budget - after 1.5999999999969532
# bits used 1364
# bit budget - after 0.3999999999969077
#  ---------
# .bits used 1363
# bit budget - after 0.19999999999686224
# bits used 1362
# bit budget - after 0.9999999999968168
#  ---------
# .bits used 1362
# bit budget - after 1.7999999999967713
# bits used 1363
# bit budget - after 1.5999999999967258
#  ---------
# .bits used 1363
# bit budget - after 1.3999999999966803
# bits used 1363
# bit budget - after 1.1999999999966349
#  ---------
# .bits used 1363
# bit budget - after 0.9999999999965894
# bits used 1282
# bit budget - after 0.7999999999965439
#  ---------
# .bits used 1363
# bit budget - after 0.5999999999964984
# bits used 1363
# bit budget - after 0.39999999999645297
#  ---------
# .bits used 1363
# bit budget - after 0.1999999999964075
#  ---------
# .bits used 1362
# bit budget - after 1.7999999999963165
# bits used 1283
# bit budget - after 0.5999999999962711
#  ---------
# .bits used 1363
# bit budget - after 0.3999999999962256
# bits used 1363
# bit budget - after 0.19999999999618012
#  ---------
# .bits used 1361
# bit budget - after 1.9999999999961346
# bits used 1364
# bit budget - after 0.7999999999960892
#  ---------
# .bits used 1363
# bit budget - after 0.5999999999960437
# bits used 1363
# bit budget - after 0.3999999999959982
#  ---------
# .bits used 1363
# bit budget - after 0.19999999999595275
# bits used 1362
# bit budget - after 0.9999999999959073
#  ---------
# .bits used 1363
# bit budget - after 0.7999999999958618
# bits used 1362
# bit budget - after 1.5999999999958163
#  ---------
# .bits used 1364
# bit budget - after 0.39999999999577085
# bits used 1363
# bit budget - after 0.19999999999572537
#  ---------
# .bits used 1361
# bit budget - after 1.99999999999568
# bits used 1364
# bit budget - after 0.7999999999956344
#  ---------
# .bits used 1363
# bit budget - after 1.3999999999955435
#  ---------
# .bits used 1283
# bit budget - after 0.199999999995498
#  ---------
# .bits used 1282
# bit budget - after 1.799999999995407
# bits used 1282
# bit budget - after 1.5999999999953616
#  ---------
# .bits used 1287
# bit budget - after 1.399999999995316
# bits used 1285
# bit budget - after 0.19999999999527063
#  ---------
# .bits used 1286
# bit budget - after 0.9999999999952252
# bits used 1285
# bit budget - after 0.7999999999951797
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999951342
# bits used 1287
# bit budget - after 0.39999999999508873
#  ---------
# .bits used 1282
# bit budget - after 0.19999999999504325
# bits used 1283
# bit budget - after 0.9999999999949978
#  ---------
# .bits used 1282
# bit budget - after 1.5999999999949068
#  ---------
# .bits used 1287
# bit budget - after 1.3999999999948614
# bits used 1287
# bit budget - after 1.1999999999948159
#  ---------
# .bits used 1287
# bit budget - after 0.9999999999947704
# bits used 1284
# bit budget - after 0.7999999999947249
#  ---------
# .bits used 1286
# bit budget - after 0.5999999999946795
# bits used 1285
# bit budget - after 1.399999999994634
#  ---------
# .bits used 1363
# bit budget - after 1.1999999999945885
# bits used 1363
# bit budget - after 0.999999999994543
#  ---------
# .bits used 1365
# bit budget - after 1.7999999999944976
# bits used 1285
# bit budget - after 1.599999999994452
#  ---------
# .bits used 1364
# bit budget - after 0.3999999999944066
# bits used 1284
# bit budget - after 1.1999999999943611
#  ---------
# .bits used 1366
# bit budget - after 0.9999999999943157
# bits used 1285
# bit budget - after 0.7999999999942702
#  ---------
# .bits used 1367
# bit budget - after 1.5999999999942247
# bits used 1367
# bit budget - after 0.39999999999417923
#  ---------
# .bits used 1363
# bit budget - after 0.19999999999413376
# bits used 1283
# bit budget - after 1.9999999999940883
#  ---------
# .bits used 1369
# bit budget - after 0.7999999999940428
# bits used 1287
# bit budget - after 0.5999999999939973
#  ---------
# .bits used 1282
# bit budget - after 0.39999999999395186
# bits used 1284
# bit budget - after 0.19999999999390639
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999938609
# bits used 1285
# bit budget - after 0.7999999999938154
#  ---------
# .bits used 1283
# bit budget - after 0.3999999999937245
#  ---------
# .bits used 1287
# bit budget - after 0.199999999993679
# bits used 1288
# bit budget - after 0.9999999999936335
#  ---------
# .bits used 1282
# bit budget - after 1.5999999999935426
#  ---------
# .bits used 1282
# bit budget - after 1.3999999999934971
# bits used 1283
# bit budget - after 0.19999999999345164
#  ---------
# . ---------
# .bits used 1285
# bit budget - after 0.5999999999933152
# bits used 1284
# bit budget - after 0.39999999999326974
#  ---------
# .bits used 1285
# bit budget - after 0.19999999999322426
# bits used 1283
# bit budget - after 0.9999999999931788
#  ---------
# .bits used 1286
# bit budget - after 0.7999999999931333
# bits used 1284
# bit budget - after 0.5999999999930878
#  ---------
# .bits used 1282
# bit budget - after 0.39999999999304237
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999929514
# bits used 1286
# bit budget - after 1.799999999992906
#  ---------
# .bits used 1284
# bit budget - after 1.5999999999928605
# bits used 1288
# bit budget - after 0.399999999992815
#  ---------
# .bits used 1284
# bit budget - after 1.999999999992724
#  ---------
# .bits used 1286
# bit budget - after 0.7999999999926786
# bits used 1286
# bit budget - after 1.599999999992633
#  ---------
# .bits used 1282
# bit budget - after 1.3999999999925876
# bits used 1282
# bit budget - after 1.1999999999925421
#  ---------
# .bits used 1282
# bit budget - after 0.9999999999924967
#  ---------
# .bits used 1287
# bit budget - after 0.5999999999924057
# bits used 1286
# bit budget - after 1.3999999999923602
#  ---------
# .bits used 1286
# bit budget - after 0.19999999999231477
# bits used 1284
# bit budget - after 0.9999999999922693
#  ---------
# .bits used 1284
# bit budget - after 1.7999999999922238
# bits used 1282
# bit budget - after 1.5999999999921783
#  ---------
# .bits used 1282
# bit budget - after 1.3999999999921329
# bits used 1285
# bit budget - after 0.1999999999920874
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999920419
# bits used 1282
# bit budget - after 0.7999999999919964
#  ---------
# .bits used 1287
# bit budget - after 0.599999999991951
# bits used 1288
# bit budget - after 1.3999999999919055
#  ---------
# .bits used 1287
# bit budget - after 0.19999999999186002
# bits used 1283
# bit budget - after 0.9999999999918145
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999917691
# bits used 1284
# bit budget - after 0.5999999999917236
#  ---------
# .bits used 1287
# bit budget - after 0.3999999999916781
# bits used 1366
# bit budget - after 0.19999999999163265
#  ---------
# .bits used 1363
# bit budget - after 1.9999999999915872
# bits used 1285
# bit budget - after 1.7999999999915417
#  ---------
# .bits used 1285
# bit budget - after 0.5999999999914962
# bits used 1284
# bit budget - after 0.39999999999145075
#  ---------
# .bits used 1287
# bit budget - after 0.19999999999140528
# bits used 1285
# bit budget - after 1.9999999999913598
#  ---------
# .bits used 1285
# bit budget - after 1.7999999999913143
# bits used 1285
# bit budget - after 0.5999999999912689
#  ---------
# .bits used 1284
# bit budget - after 1.199999999991178
#  ---------
# .bits used 1286
# bit budget - after 0.9999999999911324
# bits used 1283
# bit budget - after 1.799999999991087
#  ---------
# .bits used 1286
# bit budget - after 0.5999999999910415
# bits used 1285
# bit budget - after 0.399999999990996
#  ---------
# .bits used 1285
# bit budget - after 0.19999999999095053
# bits used 1283
# bit budget - after 0.999999999990905
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999908596
# bits used 1282
# bit budget - after 0.5999999999908141
#  ---------
# .bits used 1287
# bit budget - after 0.39999999999076863
# bits used 1282
# bit budget - after 0.19999999999072315
#  ---------
# .bits used 1284
# bit budget - after 1.9999999999906777
# bits used 1368
# bit budget - after 1.7999999999906322
#  ---------
# .bits used 1367
# bit budget - after 0.5999999999905867
# bits used 1363
# bit budget - after 0.39999999999054126
#  ---------
# .bits used 1282
# bit budget - after 0.19999999999049578
# bits used 1365
# bit budget - after 0.9999999999904503
#  ---------
# .bits used 1371
# bit budget - after 0.7999999999904048
# bits used 1363
# bit budget - after 0.5999999999903594
#  ---------
# .bits used 1284
# bit budget - after 1.3999999999903139
# bits used 1369
# bit budget - after 0.1999999999902684
#  ---------
# .bits used 1366
# bit budget - after 0.7999999999901775
#  ---------
# .bits used 1282
# bit budget - after 0.599999999990132
# bits used 1284
# bit budget - after 0.3999999999900865
#  ---------
# .bits used 1285
# bit budget - after 0.19999999999004103
# bits used 1284
# bit budget - after 0.9999999999899956
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999899501
# bits used 1287
# bit budget - after 0.5999999999899046
#  ---------
# .bits used 1286
# bit budget - after 1.3999999999898591
# bits used 1286
# bit budget - after 0.19999999998981366
#  ---------
# .bits used 1283
# bit budget - after 0.9999999999897682
# bits used 1284
# bit budget - after 0.7999999999897227
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999896772
# bits used 1282
# bit budget - after 0.39999999998963176
#  ---------
# .bits used 1285
# bit budget - after 0.19999999998958629
#  ---------
# .bits used 1284
# bit budget - after 0.7999999999894953
# bits used 1282
# bit budget - after 0.5999999999894499
#  ---------
# .bits used 1282
# bit budget - after 0.3999999999894044
# bits used 1282
# bit budget - after 0.1999999999893589
#  ---------
# .bits used 1283
# bit budget - after 1.9999999999893134
# bits used 1288
# bit budget - after 0.799999999989268
#  ---------
# .bits used 1285
# bit budget - after 0.5999999999892225
# bits used 1284
# bit budget - after 0.399999999989177
#  ---------
# . ---------
# .bits used 1282
# bit budget - after 1.7999999999890406
# bits used 1285
# bit budget - after 0.5999999999889951
#  ---------
# .bits used 1284
# bit budget - after 0.39999999998894964
# bits used 1284
# bit budget - after 0.19999999998890416
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999888132
#  ---------
# .bits used 1285
# bit budget - after 0.39999999998872227
#  ---------
# .bits used 1284
# bit budget - after 1.1999999999886768
# bits used 1287
# bit budget - after 0.9999999999886313
#  ---------
# .bits used 1285
# bit budget - after 0.7999999999885858
# bits used 1282
# bit budget - after 0.5999999999885404
#  ---------
# .bits used 1282
# bit budget - after 0.3999999999884949
# bits used 1282
# bit budget - after 0.19999999998844942
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999884039
# bits used 1282
# bit budget - after 0.7999999999883585
#  ---------
# .bits used 1282
# bit budget - after 0.599999999988313
#  ---------
# .bits used 1283
# bit budget - after 0.19999999998822204
#  ---------
# .bits used 1284
# bit budget - after 0.7999999999881311
# bits used 1287
# bit budget - after 0.5999999999880856
#  ---------
# .bits used 1288
# bit budget - after 0.19999999998799467
#  ---------
# .bits used 1283
# bit budget - after 0.9999999999879492
# bits used 1282
# bit budget - after 0.7999999999879037
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999878582
# bits used 1286
# bit budget - after 0.39999999998781277
#  ---------
# .bits used 1284
# bit budget - after 0.1999999999877673
# bits used 1283
# bit budget - after 0.9999999999877218
#  ---------
# .bits used 1283
# bit budget - after 0.5999999999876309
#  ---------
# .bits used 1282
# bit budget - after 0.3999999999875854
#  ---------
# .bits used 1282
# bit budget - after 0.9999999999874944
# bits used 1284
# bit budget - after 0.799999999987449
#  ---------
# .bits used 1285
# bit budget - after 0.5999999999874035
# bits used 1285
# bit budget - after 0.399999999987358
#  ---------
# .bits used 1282
# bit budget - after 0.19999999998731255
# bits used 1283
# bit budget - after 0.9999999999872671
#  ---------
# .bits used 1286
# bit budget - after 0.5999999999871761
#  ---------
# .bits used 1285
# bit budget - after 0.39999999998713065
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999870397
# bits used 1284
# bit budget - after 0.7999999999869942
#  ---------
# .bits used 1282
# bit budget - after 0.5999999999869488
# bits used 1285
# bit budget - after 0.3999999999869033
#  ---------
# .bits used 1365
# bit budget - after 0.1999999999868578
# bits used 1286
# bit budget - after 0.9999999999868123
#  ---------
# .bits used 1286
# bit budget - after 0.7999999999867669
# bits used 1284
# bit budget - after 0.5999999999867214
#  ---------
# .bits used 1287
# bit budget - after 0.3999999999866759
# bits used 1363
# bit budget - after 0.19999999998663043
#  ---------
# .bits used 1362
# bit budget - after 0.999999999986585
# bits used 1366
# bit budget - after 0.7999999999865395
#  ---------
# .bits used 1285
# bit budget - after 0.599999999986494
# bits used 1370
# bit budget - after 0.39999999998644853
#  ---------
# .bits used 1282
# bit budget - after 0.19999999998640305
# bits used 1362
# bit budget - after 0.9999999999863576
#  ---------
# .bits used 1287
# bit budget - after 0.7999999999863121
# bits used 1365
# bit budget - after 1.5999999999862666
#  ---------
# .bits used 1287
# bit budget - after 1.3999999999862212
# bits used 1286
# bit budget - after 1.1999999999861757
#  ---------
# .bits used 1282
# bit budget - after 0.9999999999861302
# bits used 1283
# bit budget - after 1.7999999999860847
#  ---------
# .bits used 1290
# bit budget - after 0.5999999999860393
# bits used 1287
# bit budget - after 0.3999999999859938
#  ---------
# .bits used 1287
# bit budget - after 0.1999999999859483
# bits used 1284
# bit budget - after 0.9999999999859028
#  ---------
# .bits used 1284
# bit budget - after 0.7999999999858574
# bits used 1285
# bit budget - after 1.5999999999858119
#  ---------
# .bits used 1288
# bit budget - after 0.3999999999857664
# bits used 1287
# bit budget - after 0.19999999998572093
#  ---------
# .bits used 1286
# bit budget - after 0.9999999999856755
# bits used 1282
# bit budget - after 0.79999999998563
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999855845
# bits used 1284
# bit budget - after 0.39999999998553903
#  ---------
# .bits used 1284
# bit budget - after 0.19999999998549356
# bits used 1282
# bit budget - after 1.999999999985448
#  ---------
# .bits used 1282
# bit budget - after 1.7999999999854026
# bits used 1285
# bit budget - after 0.5999999999853571
#  ---------
# .bits used 1286
# bit budget - after 1.3999999999853117
# bits used 1285
# bit budget - after 0.19999999998526619
#  ---------
# .bits used 1283
# bit budget - after 1.9999999999852207
# bits used 1285
# bit budget - after 1.7999999999851752
#  ---------
# .bits used 1286
# bit budget - after 0.5999999999851298
# bits used 1282
# bit budget - after 0.3999999999850843
#  ---------
# .bits used 1282
# bit budget - after 0.1999999999850388
# bits used 1363
# bit budget - after 1.9999999999849933
#  ---------
# .bits used 1288
# bit budget - after 0.7999999999849479
# bits used 1284
# bit budget - after 0.5999999999849024
#  ---------
# .bits used 1283
# bit budget - after 0.19999999998481144
#  ---------
# .bits used 1286
# bit budget - after 0.999999999984766
# bits used 1287
# bit budget - after 0.7999999999847205
#  ---------
# .bits used 1287
# bit budget - after 0.599999999984675
# bits used 1284
# bit budget - after 0.39999999998462954
#  ---------
# .bits used 1284
# bit budget - after 0.19999999998458406
# bits used 1283
# bit budget - after 0.9999999999845386
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999844931
# bits used 1285
# bit budget - after 0.5999999999844476
#  ---------
# .bits used 1282
# bit budget - after 0.39999999998440217
# bits used 1284
# bit budget - after 0.1999999999843567
#  ---------
# .bits used 1283
# bit budget - after 0.9999999999843112
# bits used 1284
# bit budget - after 0.7999999999842657
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999842203
#  ---------
# .bits used 1283
# bit budget - after 0.19999999998412932
# bits used 1284
# bit budget - after 1.9999999999840838
#  ---------
# .bits used 1282
# bit budget - after 1.7999999999840384
# bits used 1283
# bit budget - after 0.5999999999839929
#  ---------
# .bits used 1287
# bit budget - after 0.3999999999839474
# bits used 1287
# bit budget - after 0.19999999998390194
#  ---------
# .bits used 1364
# bit budget - after 0.9999999999838565
# bits used 1286
# bit budget - after 1.799999999983811
#  ---------
# .bits used 1282
# bit budget - after 1.5999999999837655
# bits used 1283
# bit budget - after 0.39999999998372004
#  ---------
# .bits used 1287
# bit budget - after 0.19999999998367457
# bits used 1284
# bit budget - after 0.9999999999836291
#  ---------
# .bits used 1284
# bit budget - after 0.7999999999835836
# bits used 1283
# bit budget - after 1.5999999999835381
#  ---------
# .bits used 1286
# bit budget - after 0.39999999998349267
# bits used 1287
# bit budget - after 0.1999999999834472
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999834017
# bits used 1284
# bit budget - after 1.7999999999833562
#  ---------
# .bits used 1286
# bit budget - after 0.5999999999833108
# bits used 1284
# bit budget - after 1.3999999999832653
#  ---------
# .bits used 1283
# bit budget - after 0.19999999998321982
#  ---------
# .bits used 1287
# bit budget - after 0.7999999999831289
#  ---------
# .bits used 1283
# bit budget - after 0.3999999999830379
# bits used 1282
# bit budget - after 0.19999999998299245
#  ---------
# .bits used 1284
# bit budget - after 0.999999999982947
# bits used 1282
# bit budget - after 0.7999999999829015
#  ---------
# .bits used 1287
# bit budget - after 0.599999999982856
# bits used 1285
# bit budget - after 0.39999999998281055
#  ---------
# .bits used 1363
# bit budget - after 0.19999999998276508
# bits used 1365
# bit budget - after 0.9999999999827196
#  ---------
# .bits used 1284
# bit budget - after 1.7999999999826741
# bits used 1364
# bit budget - after 0.5999999999826287
#  ---------
# .bits used 1366
# bit budget - after 0.3999999999825832
# bits used 1362
# bit budget - after 1.1999999999825377
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999824922
# bits used 1367
# bit budget - after 0.7999999999824468
#  ---------
# .bits used 1363
# bit budget - after 0.5999999999824013
# bits used 1282
# bit budget - after 0.3999999999823558
#  ---------
# .bits used 1286
# bit budget - after 1.1999999999823103
# bits used 1284
# bit budget - after 1.9999999999822649
#  ---------
# .bits used 1290
# bit budget - after 0.7999999999822194
# bits used 1287
# bit budget - after 0.5999999999821739
#  ---------
# .bits used 1284
# bit budget - after 0.39999999998212843
# bits used 1283
# bit budget - after 1.199999999982083
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999820375
# bits used 1282
# bit budget - after 0.799999999981992
#  ---------
# .bits used 1282
# bit budget - after 0.5999999999819465
# bits used 1284
# bit budget - after 0.39999999998190106
#  ---------
# .bits used 1284
# bit budget - after 1.1999999999818556
# bits used 1282
# bit budget - after 0.9999999999818101
#  ---------
# .bits used 1283
# bit budget - after 0.5999999999817192
#  ---------
# .bits used 1284
# bit budget - after 0.3999999999816737
#  ---------
# .bits used 1284
# bit budget - after 1.9999999999815827
# bits used 1288
# bit budget - after 0.7999999999815373
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999814918
# bits used 1282
# bit budget - after 0.3999999999814463
#  ---------
# .bits used 1285
# bit budget - after 0.19999999998140083
#  ---------
# .bits used 1289
# bit budget - after 1.7999999999813099
# bits used 1284
# bit budget - after 1.5999999999812644
#  ---------
# .bits used 1283
# bit budget - after 0.39999999998121893
# bits used 1285
# bit budget - after 0.19999999998117346
#  ---------
# .bits used 1283
# bit budget - after 0.999999999981128
# bits used 1287
# bit budget - after 0.7999999999810825
#  ---------
# .bits used 1282
# bit budget - after 0.599999999981037
# bits used 1282
# bit budget - after 0.39999999998099156
#  ---------
# .bits used 1284
# bit budget - after 0.19999999998094609
# bits used 1286
# bit budget - after 0.9999999999809006
#  ---------
# .bits used 1364
# bit budget - after 1.7999999999808551
# bits used 1288
# bit budget - after 0.5999999999808097
#  ---------
# .bits used 1366
# bit budget - after 0.3999999999807642
# bits used 1287
# bit budget - after 0.1999999999807187
#  ---------
# .bits used 1367
# bit budget - after 0.9999999999806732
# bits used 1366
# bit budget - after 0.7999999999806278
#  ---------
# .bits used 1367
# bit budget - after 1.5999999999805823
# bits used 1367
# bit budget - after 0.3999999999805368
#  ---------
# .bits used 1287
# bit budget - after 0.19999999998049134
#  ---------
# .bits used 1287
# bit budget - after 0.7999999999804004
# bits used 1283
# bit budget - after 1.599999999980355
#  ---------
# .bits used 1284
# bit budget - after 1.3999999999803094
# bits used 1282
# bit budget - after 1.199999999980264
#  ---------
# .bits used 1287
# bit budget - after 0.9999999999802185
# bits used 1366
# bit budget - after 0.799999999980173
#  ---------
# .bits used 1282
# bit budget - after 0.5999999999801275
# bits used 1284
# bit budget - after 0.39999999998008207
#  ---------
# .bits used 1289
# bit budget - after 0.1999999999800366
# bits used 1286
# bit budget - after 0.9999999999799911
#  ---------
# .bits used 1285
# bit budget - after 1.7999999999799456
# bits used 1283
# bit budget - after 0.5999999999799002
#  ---------
# .bits used 1284
# bit budget - after 0.3999999999798547
# bits used 1284
# bit budget - after 1.1999999999798092
#  ---------
# .bits used 1285
# bit budget - after 0.9999999999797637
# bits used 1285
# bit budget - after 0.7999999999797183
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999796728
# bits used 1284
# bit budget - after 0.3999999999796273
#  ---------
# .bits used 1282
# bit budget - after 0.19999999997958184
# bits used 1283
# bit budget - after 1.9999999999795364
#  ---------
# .bits used 1283
# bit budget - after 0.7999999999794909
# bits used 1288
# bit budget - after 1.5999999999794454
#  ---------
# .bits used 1287
# bit budget - after 1.3999999999794
# bits used 1288
# bit budget - after 1.1999999999793545
#  ---------
# .bits used 1284
# bit budget - after 0.999999999979309
# bits used 1284
# bit budget - after 0.7999999999792635
#  ---------
# .bits used 1287
# bit budget - after 0.599999999979218
# bits used 1286
# bit budget - after 0.39999999997917257
#  ---------
# .bits used 1284
# bit budget - after 0.1999999999791271
#  ---------
# .bits used 1285
# bit budget - after 1.7999999999790361
# bits used 1287
# bit budget - after 1.5999999999789907
#  ---------
# .bits used 1287
# bit budget - after 1.3999999999789452
# bits used 1287
# bit budget - after 0.19999999997889972
#  ---------
# .bits used 1362
# bit budget - after 0.9999999999788542
# bits used 1285
# bit budget - after 0.7999999999788088
#  ---------
# .bits used 1363
# bit budget - after 0.5999999999787633
# bits used 1363
# bit budget - after 0.3999999999787178
#  ---------
# .bits used 1363
# bit budget - after 0.19999999997867235
# bits used 1365
# bit budget - after 0.9999999999786269
#  ---------
# .bits used 1365
# bit budget - after 1.7999999999785814
# bits used 1366
# bit budget - after 1.599999999978536
#  ---------
# .bits used 1286
# bit budget - after 0.39999999997849045
# bits used 1284
# bit budget - after 0.19999999997844498
#  ---------
# .bits used 1283
# bit budget - after 0.799999999978354
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999783086
#  ---------
# .bits used 1285
# bit budget - after 0.1999999999782176
# bits used 1283
# bit budget - after 0.9999999999781721
#  ---------
# .bits used 1284
# bit budget - after 0.7999999999781267
# bits used 1284
# bit budget - after 0.5999999999780812
#  ---------
# .bits used 1288
# bit budget - after 0.19999999997799023
#  ---------
# .bits used 1283
# bit budget - after 0.7999999999778993
#  ---------
# .bits used 1288
# bit budget - after 0.39999999997780833
#  ---------
# .bits used 1286
# bit budget - after 1.1999999999777629
#  ---------
# .bits used 1283
# bit budget - after 0.7999999999776719
# bits used 1282
# bit budget - after 0.5999999999776264
#  ---------
# .bits used 1285
# bit budget - after 0.39999999997758096
# bits used 1286
# bit budget - after 1.1999999999775355
#  ---------
# .bits used 1284
# bit budget - after 0.99999999997749
# bits used 1284
# bit budget - after 0.7999999999774445
#  ---------
# .bits used 1287
# bit budget - after 0.5999999999773991
# bits used 1287
# bit budget - after 0.3999999999773536
#  ---------
# .bits used 1284
# bit budget - after 0.1999999999773081
# bits used 1283
# bit budget - after 0.9999999999772626
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999772172
# bits used 1282
# bit budget - after 0.5999999999771717
#  ---------
# .bits used 1282
# bit budget - after 0.3999999999771262
#  ---------
# .bits used 1283
# bit budget - after 0.7999999999769898
#  ---------
# .bits used 1283
# bit budget - after 0.39999999997689883
#  ---------
# .bits used 1282
# bit budget - after 0.19999999997685336
# bits used 1284
# bit budget - after 0.9999999999768079
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999767624
# bits used 1282
# bit budget - after 0.5999999999767169
#  ---------
# .bits used 1284
# bit budget - after 1.3999999999766715
# bits used 1283
# bit budget - after 0.199999999976626
#  ---------
# .bits used 1288
# bit budget - after 0.9999999999765805
# bits used 1286
# bit budget - after 1.799999999976535
#  ---------
# .bits used 1369
# bit budget - after 0.5999999999764896
# bits used 1285
# bit budget - after 0.3999999999764441
#  ---------
# .bits used 1282
# bit budget - after 0.9999999999763531
#  ---------
# .bits used 1285
# bit budget - after 0.7999999999763077
# bits used 1285
# bit budget - after 0.5999999999762622
#  ---------
# .bits used 1284
# bit budget - after 0.3999999999762167
# bits used 1288
# bit budget - after 1.1999999999761712
#  ---------
# .bits used 1282
# bit budget - after 0.9999999999761258
# bits used 1284
# bit budget - after 0.7999999999760803
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999760348
# bits used 1282
# bit budget - after 0.39999999997598934
#  ---------
# .bits used 1282
# bit budget - after 0.9999999999758984
#  ---------
# .bits used 1284
# bit budget - after 1.799999999975853
# bits used 1283
# bit budget - after 0.5999999999758074
#  ---------
# .bits used 1283
# bit budget - after 0.1999999999757165
#  ---------
# .bits used 1283
# bit budget - after 0.999999999975671
# bits used 1282
# bit budget - after 0.7999999999756255
#  ---------
# .bits used 1284
# bit budget - after 1.59999999997558
# bits used 1282
# bit budget - after 1.3999999999755346
#  ---------
# .bits used 1282
# bit budget - after 1.1999999999754891
# bits used 1282
# bit budget - after 0.9999999999754436
#  ---------
# .bits used 1284
# bit budget - after 0.7999999999753982
# bits used 1282
# bit budget - after 0.5999999999753527
#  ---------
# .bits used 1282
# bit budget - after 0.3999999999753072
# bits used 1284
# bit budget - after 0.19999999997526174
#  ---------
# .bits used 1285
# bit budget - after 0.7999999999751708
#  ---------
# .bits used 1282
# bit budget - after 1.3999999999750798
#  ---------
# .bits used 1283
# bit budget - after 0.19999999997503437
# bits used 1284
# bit budget - after 1.999999999974989
#  ---------
# .bits used 1283
# bit budget - after 0.7999999999749434
# bits used 1366
# bit budget - after 0.599999999974898
#  ---------
# .bits used 1362
# bit budget - after 1.3999999999748525
# bits used 1367
# bit budget - after 0.199999999974807
#  ---------
# .bits used 1364
# bit budget - after 0.9999999999747615
# bits used 1367
# bit budget - after 1.799999999974716
#  ---------
# .bits used 1285
# bit budget - after 0.5999999999746706
# bits used 1288
# bit budget - after 1.399999999974625
#  ---------
# .bits used 1287
# bit budget - after 0.19999999997457962
# bits used 1364
# bit budget - after 0.9999999999745341
#  ---------
# .bits used 1285
# bit budget - after 0.7999999999744887
# bits used 1289
# bit budget - after 0.5999999999744432
#  ---------
# .bits used 1286
# bit budget - after 0.3999999999743977
# bits used 1282
# bit budget - after 0.19999999997435225
#  ---------
# .bits used 1284
# bit budget - after 1.7999999999742613
#  ---------
# .bits used 1289
# bit budget - after 1.5999999999742158
# bits used 1290
# bit budget - after 0.39999999997417035
#  ---------
# .bits used 1285
# bit budget - after 0.19999999997412488
# bits used 1284
# bit budget - after 0.9999999999740794
#  ---------
# .bits used 1285
# bit budget - after 0.7999999999740339
# bits used 1283
# bit budget - after 1.5999999999739885
#  ---------
# .bits used 1283
# bit budget - after 0.399999999973943
# bits used 1284
# bit budget - after 1.1999999999738975
#  ---------
# .bits used 1284
# bit budget - after 0.999999999973852
#  ---------
# .bits used 1283
# bit budget - after 0.5999999999737611
# bits used 1282
# bit budget - after 0.3999999999737156
#  ---------
# .bits used 1282
# bit budget - after 0.19999999997367013
#  ---------
# .bits used 1284
# bit budget - after 0.7999999999735792
# bits used 1284
# bit budget - after 0.5999999999735337
#  ---------
# .bits used 1284
# bit budget - after 0.39999999997348823
# bits used 1284
# bit budget - after 0.19999999997344275
#  ---------
# .bits used 1286
# bit budget - after 0.7999999999733518
#  ---------
# .bits used 1282
# bit budget - after 0.5999999999733063
# bits used 1282
# bit budget - after 0.39999999997326086
#  ---------
# .bits used 1363
# bit budget - after 0.19999999997321538
# bits used 1284
# bit budget - after 0.9999999999731699
#  ---------
# .bits used 1284
# bit budget - after 1.7999999999731244
# bits used 1282
# bit budget - after 1.599999999973079
#  ---------
# .bits used 1282
# bit budget - after 1.3999999999730335
# bits used 1283
# bit budget - after 0.199999999972988
#  ---------
# .bits used 1283
# bit budget - after 0.9999999999729425
# bits used 1285
# bit budget - after 0.7999999999728971
#  ---------
# .bits used 1282
# bit budget - after 0.5999999999728516
# bits used 1284
# bit budget - after 1.399999999972806
#  ---------
# .bits used 1286
# bit budget - after 0.19999999997276063
#  ---------
# .bits used 1284
# bit budget - after 1.7999999999726697
# bits used 1285
# bit budget - after 0.5999999999726242
#  ---------
# .bits used 1282
# bit budget - after 0.39999999997257873
# bits used 1284
# bit budget - after 1.1999999999725333
#  ---------
# .bits used 1282
# bit budget - after 0.9999999999724878
# bits used 1282
# bit budget - after 0.7999999999724423
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999723968
# bits used 1283
# bit budget - after 1.3999999999723514
#  ---------
# .bits used 1285
# bit budget - after 0.1999999999723059
# bits used 1283
# bit budget - after 0.9999999999722604
#  ---------
# .bits used 1284
# bit budget - after 0.7999999999722149
# bits used 1284
# bit budget - after 0.5999999999721695
#  ---------
# .bits used 1287
# bit budget - after 0.399999999972124
# bits used 1284
# bit budget - after 1.1999999999720785
#  ---------
# .bits used 1285
# bit budget - after 0.999999999972033
# bits used 1285
# bit budget - after 0.7999999999719876
#  ---------
# .bits used 1285
# bit budget - after 0.5999999999719421
# bits used 1284
# bit budget - after 0.3999999999718966
#  ---------
# .bits used 1284
# bit budget - after 0.19999999997185114
# bits used 1283
# bit budget - after 0.9999999999718057
#  ---------
# .bits used 1283
# bit budget - after 0.5999999999717147
#  ---------
# .bits used 1286
# bit budget - after 1.3999999999716692
# bits used 1286
# bit budget - after 0.19999999997162377
#  ---------
# .bits used 1284
# bit budget - after 0.7999999999715328
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999714873
# bits used 1282
# bit budget - after 0.39999999997144187
#  ---------
# .bits used 1285
# bit budget - after 1.1999999999713964
# bits used 1284
# bit budget - after 0.9999999999713509
#  ---------
# .bits used 1287
# bit budget - after 0.7999999999713054
# bits used 1284
# bit budget - after 1.59999999997126
#  ---------
# .bits used 1288
# bit budget - after 0.3999999999712145
# bits used 1287
# bit budget - after 0.19999999997116902
#  ---------
# .bits used 1286
# bit budget - after 0.9999999999711235
# bits used 1284
# bit budget - after 0.7999999999710781
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999710326
# bits used 1284
# bit budget - after 0.3999999999709871
#  ---------
# .bits used 1366
# bit budget - after 0.19999999997094164
# bits used 1284
# bit budget - after 0.9999999999708962
#  ---------
# .bits used 1365
# bit budget - after 0.7999999999708507
# bits used 1365
# bit budget - after 0.5999999999708052
#  ---------
# .bits used 1287
# bit budget - after 0.39999999997075975
# bits used 1366
# bit budget - after 0.19999999997071427
#  ---------
# .bits used 1362
# bit budget - after 0.9999999999706688
#  ---------
# .bits used 1286
# bit budget - after 0.5999999999705778
# bits used 1366
# bit budget - after 0.39999999997053237
#  ---------
# .bits used 1363
# bit budget - after 0.1999999999704869
# bits used 1283
# bit budget - after 0.9999999999704414
#  ---------
# .bits used 1284
# bit budget - after 1.799999999970396
# bits used 1288
# bit budget - after 0.5999999999703505
#  ---------
# .bits used 1284
# bit budget - after 0.399999999970305
# bits used 1289
# bit budget - after 0.19999999997025952
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999701686
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999701231
# bits used 1282
# bit budget - after 0.3999999999700776
#  ---------
# .bits used 1365
# bit budget - after 0.19999999997003215
# bits used 1364
# bit budget - after 0.9999999999699867
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999699412
#  ---------
# .bits used 1285
# bit budget - after 0.39999999996985025
# bits used 1285
# bit budget - after 0.19999999996980478
#  ---------
# .bits used 1283
# bit budget - after 0.9999999999697593
# bits used 1288
# bit budget - after 1.7999999999697138
#  ---------
# .bits used 1288
# bit budget - after 0.5999999999696684
# bits used 1287
# bit budget - after 0.3999999999696229
#  ---------
# .bits used 1287
# bit budget - after 0.1999999999695774
# bits used 1284
# bit budget - after 0.9999999999695319
#  ---------
# .bits used 1283
# bit budget - after 1.7999999999694865
# bits used 1286
# bit budget - after 0.599999999969441
#  ---------
# .bits used 1365
# bit budget - after 0.3999999999693955
# bits used 1364
# bit budget - after 1.19999999996935
#  ---------
# .bits used 1283
# bit budget - after 0.7999999999692591
#  ---------
# .bits used 1287
# bit budget - after 0.5999999999692136
# bits used 1284
# bit budget - after 1.3999999999691681
#  ---------
# .bits used 1283
# bit budget - after 0.19999999996912265
# bits used 1284
# bit budget - after 0.9999999999690772
#  ---------
# .bits used 1287
# bit budget - after 0.7999999999690317
# bits used 1284
# bit budget - after 0.5999999999689862
#  ---------
# .bits used 1287
# bit budget - after 0.39999999996894076
# bits used 1284
# bit budget - after 0.19999999996889528
#  ---------
# .bits used 1285
# bit budget - after 0.9999999999688498
# bits used 1289
# bit budget - after 0.7999999999688043
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999687589
# bits used 1284
# bit budget - after 0.3999999999687134
#  ---------
# . ---------
# .bits used 1285
# bit budget - after 0.799999999968577
# bits used 1284
# bit budget - after 0.5999999999685315
#  ---------
# .bits used 1282
# bit budget - after 0.399999999968486
# bits used 1284
# bit budget - after 0.19999999996844053
#  ---------
# .bits used 1283
# bit budget - after 0.9999999999683951
# bits used 1287
# bit budget - after 0.7999999999683496
#  ---------
# .bits used 1282
# bit budget - after 0.5999999999683041
# bits used 1285
# bit budget - after 0.39999999996825863
#  ---------
# .bits used 1284
# bit budget - after 0.19999999996821316
# bits used 1285
# bit budget - after 1.9999999999681677
#  ---------
# .bits used 1283
# bit budget - after 0.7999999999681222
#  ---------
# .bits used 1285
# bit budget - after 0.39999999996803126
# bits used 1282
# bit budget - after 0.1999999999679858
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999679403
#  ---------
# .bits used 1286
# bit budget - after 0.5999999999678494
# bits used 1285
# bit budget - after 0.3999999999678039
#  ---------
# .bits used 1285
# bit budget - after 0.1999999999677584
#  ---------
# .bits used 1283
# bit budget - after 0.599999999967622
#  ---------
# .bits used 1282
# bit budget - after 0.3999999999675765
# bits used 1282
# bit budget - after 0.19999999996753104
#  ---------
# .bits used 1284
# bit budget - after 1.79999999996744
#  ---------
# .bits used 1285
# bit budget - after 0.5999999999673946
# bits used 1287
# bit budget - after 0.39999999996734914
#  ---------
# .bits used 1283
# bit budget - after 1.1999999999673037
# bits used 1284
# bit budget - after 0.9999999999672582
#  ---------
# .bits used 1363
# bit budget - after 0.7999999999672127
# bits used 1362
# bit budget - after 1.5999999999671672
#  ---------
# .bits used 1364
# bit budget - after 0.39999999996712177
# bits used 1366
# bit budget - after 0.1999999999670763
#  ---------
# .bits used 1283
# bit budget - after 0.9999999999670308
# bits used 1285
# bit budget - after 0.7999999999669853
#  ---------
# .bits used 1366
# bit budget - after 0.5999999999669399
# bits used 1366
# bit budget - after 0.3999999999668944
#  ---------
# .bits used 1366
# bit budget - after 0.19999999996684892
#  ---------
# .bits used 1365
# bit budget - after 1.799999999966758
# bits used 1367
# bit budget - after 0.5999999999667125
#  ---------
# .bits used 1284
# bit budget - after 0.399999999966667
# bits used 1284
# bit budget - after 0.19999999996662154
#  ---------
# .bits used 1283
# bit budget - after 0.7999999999665306
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999664851
# bits used 1284
# bit budget - after 1.3999999999664396
#  ---------
# .bits used 1286
# bit budget - after 0.19999999996639417
# bits used 1283
# bit budget - after 1.9999999999663487
#  ---------
# .bits used 1286
# bit budget - after 1.7999999999663032
# bits used 1285
# bit budget - after 1.5999999999662577
#  ---------
# .bits used 1286
# bit budget - after 0.39999999996621227
# bits used 1284
# bit budget - after 1.1999999999661668
#  ---------
# .bits used 1282
# bit budget - after 0.9999999999661213
# bits used 1282
# bit budget - after 0.7999999999660758
#  ---------
# .bits used 1282
# bit budget - after 0.5999999999660304
# bits used 1284
# bit budget - after 1.399999999965985
#  ---------
# .bits used 1286
# bit budget - after 0.19999999996593942
# bits used 1283
# bit budget - after 1.999999999965894
#  ---------
# .bits used 1285
# bit budget - after 0.7999999999658485
# bits used 1288
# bit budget - after 1.599999999965803
#  ---------
# .bits used 1286
# bit budget - after 1.3999999999657575
# bits used 1288
# bit budget - after 0.19999999996571205
#  ---------
# .bits used 1283
# bit budget - after 0.9999999999656666
# bits used 1286
# bit budget - after 1.799999999965621
#  ---------
# .bits used 1288
# bit budget - after 0.5999999999655756
# bits used 1284
# bit budget - after 0.39999999996553015
#  ---------
# .bits used 1282
# bit budget - after 0.19999999996548468
#  ---------
# .bits used 1287
# bit budget - after 0.7999999999653937
# bits used 1282
# bit budget - after 0.5999999999653483
#  ---------
# .bits used 1362
# bit budget - after 1.3999999999653028
# bits used 1286
# bit budget - after 0.1999999999652573
#  ---------
# .bits used 1366
# bit budget - after 1.9999999999652118
# bits used 1288
# bit budget - after 0.7999999999651664
#  ---------
# .bits used 1365
# bit budget - after 1.5999999999651209
# bits used 1282
# bit budget - after 1.3999999999650754
#  ---------
# .bits used 1366
# bit budget - after 1.19999999996503
# bits used 1365
# bit budget - after 1.9999999999649845
#  ---------
# .bits used 1364
# bit budget - after 0.799999999964939
# bits used 1368
# bit budget - after 0.5999999999648935
#  ---------
# .bits used 1366
# bit budget - after 0.39999999996484803
# bits used 1286
# bit budget - after 1.1999999999648026
#  ---------
# .bits used 1282
# bit budget - after 0.9999999999647571
# bits used 1284
# bit budget - after 1.7999999999647116
#  ---------
# .bits used 1288
# bit budget - after 0.5999999999646661
# bits used 1285
# bit budget - after 0.39999999996462066
#  ---------
# .bits used 1286
# bit budget - after 0.19999999996457518
# bits used 1365
# bit budget - after 0.9999999999645297
#  ---------
# .bits used 1286
# bit budget - after 1.7999999999644842
# bits used 1288
# bit budget - after 0.5999999999644388
#  ---------
# .bits used 1289
# bit budget - after 0.3999999999643933
# bits used 1282
# bit budget - after 0.1999999999643478
#  ---------
# .bits used 1287
# bit budget - after 1.9999999999643023
# bits used 1288
# bit budget - after 0.7999999999642569
#  ---------
# .bits used 1284
# bit budget - after 1.5999999999642114
# bits used 1285
# bit budget - after 1.399999999964166
#  ---------
# .bits used 1285
# bit budget - after 0.19999999996412043
#  ---------
# .bits used 1287
# bit budget - after 0.7999999999640295
# bits used 1285
# bit budget - after 0.599999999963984
#  ---------
# .bits used 1284
# bit budget - after 0.39999999996393854
# bits used 1284
# bit budget - after 0.19999999996389306
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999638476
# bits used 1284
# bit budget - after 0.7999999999638021
#  ---------
# .bits used 1285
# bit budget - after 1.3999999999637112
#  ---------
# .bits used 1282
# bit budget - after 1.1999999999636657
# bits used 1285
# bit budget - after 0.9999999999636202
#  ---------
# .bits used 1286
# bit budget - after 1.7999999999635747
# bits used 1285
# bit budget - after 0.5999999999635293
#  ---------
# .bits used 1286
# bit budget - after 1.3999999999634838
# bits used 1285
# bit budget - after 0.1999999999634383
#  ---------
# . ---------
# .bits used 1282
# bit budget - after 1.5999999999633019
# bits used 1283
# bit budget - after 0.3999999999632564
#  ---------
# .bits used 1286
# bit budget - after 1.9999999999631655
#  ---------
# .bits used 1282
# bit budget - after 1.79999999996312
# bits used 1363
# bit budget - after 1.5999999999630745
#  ---------
# .bits used 1366
# bit budget - after 0.39999999996302904
# bits used 1363
# bit budget - after 0.19999999996298357
#  ---------
# .bits used 1367
# bit budget - after 0.9999999999629381
# bits used 1367
# bit budget - after 1.7999999999628926
#  ---------
# .bits used 1366
# bit budget - after 1.5999999999628471
# bits used 1366
# bit budget - after 0.39999999996280167
#  ---------
# .bits used 1366
# bit budget - after 0.1999999999627562
# bits used 1283
# bit budget - after 1.9999999999627107
#  ---------
# .bits used 1282
# bit budget - after 1.7999999999626652
# bits used 1285
# bit budget - after 0.5999999999626198
#  ---------
# .bits used 1284
# bit budget - after 0.3999999999625743
# bits used 1284
# bit budget - after 0.19999999996252882
#  ---------
# .bits used 1285
# bit budget - after 0.7999999999624379
#  ---------
# .bits used 1287
# bit budget - after 0.5999999999623924
# bits used 1285
# bit budget - after 0.3999999999623469
#  ---------
# .bits used 1287
# bit budget - after 0.19999999996230144
# bits used 1286
# bit budget - after 0.999999999962256
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999622105
#  ---------
# .bits used 1287
# bit budget - after 1.3999999999621195
# bits used 1286
# bit budget - after 0.19999999996207407
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999620286
# bits used 1285
# bit budget - after 0.7999999999619831
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999619376
# bits used 1284
# bit budget - after 0.39999999996189217
#  ---------
# .bits used 1365
# bit budget - after 0.1999999999618467
# bits used 1286
# bit budget - after 0.9999999999618012
#  ---------
# .bits used 1284
# bit budget - after 0.7999999999617557
# bits used 1287
# bit budget - after 0.5999999999617103
#  ---------
# .bits used 1282
# bit budget - after 0.3999999999616648
# bits used 1282
# bit budget - after 0.19999999996161932
#  ---------
# .bits used 1283
# bit budget - after 0.9999999999615738
# bits used 1286
# bit budget - after 1.7999999999615284
#  ---------
# .bits used 1290
# bit budget - after 0.5999999999614829
# bits used 1287
# bit budget - after 0.3999999999614374
#  ---------
# .bits used 1284
# bit budget - after 1.199999999961392
# bits used 1285
# bit budget - after 0.9999999999613465
#  ---------
# .bits used 1284
# bit budget - after 0.799999999961301
# bits used 1282
# bit budget - after 0.5999999999612555
#  ---------
# .bits used 1284
# bit budget - after 0.39999999996121005
# bits used 1286
# bit budget - after 0.19999999996116458
#  ---------
# .bits used 1288
# bit budget - after 0.9999999999611191
# bits used 1282
# bit budget - after 0.7999999999610736
#  ---------
# .bits used 1286
# bit budget - after 1.5999999999610282
# bits used 1285
# bit budget - after 0.3999999999609827
#  ---------
# .bits used 1282
# bit budget - after 0.1999999999609372
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999608463
#  ---------
# .bits used 1285
# bit budget - after 0.3999999999607553
# bits used 1284
# bit budget - after 0.19999999996070983
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999606189
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999605734
# bits used 1286
# bit budget - after 1.399999999960528
#  ---------
# .bits used 1282
# bit budget - after 1.1999999999604825
#  ---------
# .bits used 1288
# bit budget - after 0.7999999999603915
# bits used 1286
# bit budget - after 1.599999999960346
#  ---------
# .bits used 1365
# bit budget - after 1.3999999999603006
# bits used 1285
# bit budget - after 0.19999999996025508
#  ---------
# .bits used 1283
# bit budget - after 0.9999999999602096
# bits used 1282
# ...
#  ---------
# .bits used 1286
# bit budget - after 1.7999999999535703
# bits used 1285
# bit budget - after 0.5999999999535248
#  ---------
# .bits used 1285
# bit budget - after 0.39999999995347935
# bits used 1284
# bit budget - after 0.19999999995343387
#  ---------
# .bits used 1286
# bit budget - after 0.7999999999533429
#  ---------
# .bits used 1287
# bit budget - after 0.5999999999532974
# bits used 1284
# bit budget - after 0.399999999953252
#  ---------
# .bits used 1284
# bit budget - after 0.1999999999532065
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999531155
# bits used 1284
# bit budget - after 0.5999999999530701
#  ---------
# .bits used 1366
# bit budget - after 0.3999999999530246
#  ---------
# .bits used 1284
# bit budget - after 1.9999999999529336
# bits used 1289
# bit budget - after 1.7999999999528882
#  ---------
# .bits used 1283
# bit budget - after 0.5999999999528427
# bits used 1282
# bit budget - after 0.3999999999527972
#  ---------
# .bits used 1284
# bit budget - after 1.1999999999527518
# bits used 1282
# bit budget - after 0.9999999999527063
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999526608
# bits used 1284
# bit budget - after 0.5999999999526153
#  ---------
# .bits used 1284
# bit budget - after 0.39999999995256985
#  ---------
# .bits used 1286
# bit budget - after 0.7999999999524334
#  ---------
# .bits used 1285
# bit budget - after 0.599999999952388
# bits used 1284
# bit budget - after 1.3999999999523425
#  ---------
# .bits used 1285
# bit budget - after 1.199999999952297
# bits used 1282
# bit budget - after 0.9999999999522515
#  ---------
# .bits used 1283
# bit budget - after 1.799999999952206
# bits used 1285
# bit budget - after 0.5999999999521606
#  ---------
# .bits used 1284
# bit budget - after 0.3999999999521151
# bits used 1282
# bit budget - after 0.19999999995206963
#  ---------
# .bits used 1283
# bit budget - after 0.9999999999520242
# bits used 1284
# bit budget - after 0.7999999999519787
#  ---------
# .bits used 1287
# bit budget - after 0.5999999999519332
# bits used 1282
# bit budget - after 0.39999999995188773
#  ---------
# .bits used 1282
# bit budget - after 0.19999999995184226
#  ---------
# .bits used 1282
# bit budget - after 0.7999999999517513
# bits used 1286
# bit budget - after 1.5999999999517058
#  ---------
# .bits used 1365
# bit budget - after 1.3999999999516604
# bits used 1369
# bit budget - after 0.19999999995161488
#  ---------
# .bits used 1361
# bit budget - after 1.9999999999515694
# bits used 1367
# bit budget - after 0.7999999999515239
#  ---------
# .bits used 1362
# bit budget - after 1.5999999999514785
# bits used 1368
# bit budget - after 1.399999999951433
#  ---------
# .bits used 1366
# bit budget - after 0.1999999999513875
# bits used 1362
# bit budget - after 0.999999999951342
#  ---------
# .bits used 1367
# bit budget - after 1.7999999999512966
# bits used 1364
# bit budget - after 0.5999999999512511
#  ---------
# .bits used 1286
# bit budget - after 0.3999999999512056
# bits used 1284
# bit budget - after 0.19999999995116013
#  ---------
# .bits used 1283
# bit budget - after 0.9999999999511147
# bits used 1284
# bit budget - after 0.7999999999510692
#  ---------
# .bits used 1284
# bit budget - after 0.5999999999510237
# bits used 1282
# bit budget - after 0.39999999995097824
#  ---------
# .bits used 1289
# bit budget - after 0.19999999995093276
# bits used 1286
# bit budget - after 0.9999999999508873
#  ---------
# .bits used 1286
# bit budget - after 1.7999999999508418
# bits used 1283
# bit budget - after 0.5999999999507963
#  ---------
# .bits used 1284
# bit budget - after 0.39999999995075086
# bits used 1282
# bit budget - after 0.1999999999507054
#  ---------
# .bits used 1283
# bit budget - after 0.7999999999506144
#  ---------
# .bits used 1283
# bit budget - after 0.3999999999505235
#  ---------
# .bits used 1282
# bit budget - after 0.9999999999504325
#  ---------
# .bits used 1288
# bit budget - after 0.5999999999503416
#  ---------
# .bits used 1284
# bit budget - after 0.3999999999502961
# bits used 1284
# bit budget - after 0.19999999995025064
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999502052
# bits used 1285
# bit budget - after 0.7999999999501597
#  ---------
# .bits used 1286
# bit budget - after 1.5999999999501142
# bits used 1285
# bit budget - after 0.39999999995006874
#  ---------
# .bits used 1284
# bit budget - after 0.19999999995002327
#  ---------
# .bits used 1288
# bit budget - after 0.7999999999499323
# bits used 1284
# bit budget - after 0.5999999999498868
#  ---------
# .bits used 1282
# bit budget - after 1.199999999949796
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999497504
# bits used 1284
# bit budget - after 0.7999999999497049
#  ---------
# .bits used 1366
# bit budget - after 0.5999999999496595
# bits used 1282
# bit budget - after 0.399999999949614
#  ---------
# .bits used 1363
# bit budget - after 0.19999999994956852
# bits used 1286
# bit budget - after 0.999999999949523
#  ---------
# .bits used 1363
# bit budget - after 0.7999999999494776
# bits used 1366
# bit budget - after 0.5999999999494321
#  ---------
# .bits used 1367
# bit budget - after 0.3999999999493866
# bits used 1365
# bit budget - after 0.19999999994934115
#  ---------
# .bits used 1362
# bit budget - after 0.9999999999492957
#  ---------
# .bits used 1366
# bit budget - after 0.5999999999492047
# bits used 1287
# bit budget - after 0.39999999994915925
#  ---------
# .bits used 1282
# bit budget - after 0.19999999994911377
# bits used 1362
# bit budget - after 0.9999999999490683
#  ---------
# .bits used 1287
# bit budget - after 0.7999999999490228
# bits used 1282
# bit budget - after 0.5999999999489773
#  ---------
# .bits used 1282
# bit budget - after 0.3999999999489319
#  ---------
# .bits used 1287
# bit budget - after 0.9999999999488409
# bits used 1286
# bit budget - after 1.7999999999487954
#  ---------
# .bits used 1285
# bit budget - after 1.59999999994875
# bits used 1285
# bit budget - after 0.3999999999487045
#  ---------
# .bits used 1285
# bit budget - after 0.19999999994865902
# bits used 1286
# bit budget - after 0.9999999999486135
#  ---------
# .bits used 1283
# bit budget - after 0.5999999999485226
#  ---------
# .bits used 1284
# bit budget - after 0.3999999999484771
# bits used 1284
# bit budget - after 0.19999999994843165
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999483862
# bits used 1282
# bit budget - after 0.7999999999483407
#  ---------
# .bits used 1285
# bit budget - after 0.5999999999482952
# bits used 1285
# bit budget - after 0.39999999994824975
#  ---------
# .bits used 1284
# bit budget - after 0.19999999994820428
#  ---------
# .bits used 1285
# bit budget - after 0.7999999999481133
# bits used 1284
# bit budget - after 0.5999999999480679
#  ---------
# .bits used 1287
# bit budget - after 0.3999999999480224
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999479314
# bits used 1284
# bit budget - after 0.799999999947886
#  ---------
# .bits used 1287
# bit budget - after 0.5999999999478405
# bits used 1282
# bit budget - after 0.399999999947795
#  ---------
# .bits used 1287
# bit budget - after 0.999999999947704
#  ---------
# .bits used 1287
# bit budget - after 0.7999999999476586
# bits used 1285
# bit budget - after 0.5999999999476131
#  ---------
# .bits used 1285
# bit budget - after 0.39999999994756763
# bits used 1362
# bit budget - after 1.1999999999475222
#  ---------
# .bits used 1366
# bit budget - after 0.9999999999474767
# bits used 1363
# bit budget - after 0.7999999999474312
#  ---------
# .bits used 1365
# bit budget - after 0.5999999999473857
# bits used 1285
# bit budget - after 0.39999999994734026
#  ---------
# .bits used 1363
# bit budget - after 0.19999999994729478
#  ---------
# .bits used 1363
# bit budget - after 1.7999999999472038
# bits used 1366
# bit budget - after 1.5999999999471584
#  ---------
# .bits used 1287
# bit budget - after 1.3999999999471129
# bits used 1369
# bit budget - after 0.1999999999470674
#  ---------
# .bits used 1284
# bit budget - after 0.9999999999470219
# bits used 1366
# bit budget - after 0.7999999999469765
#  ---------
# .bits used 1285
# bit budget - after 0.599999999946931
# bits used 1287
# bit budget - after 0.3999999999468855
#  ---------
# .bits used 1284
# bit budget - after 1.19999999994684
# bits used 1282
# bit budget - after 0.9999999999467946
#  ---------
# .bits used 1284
# bit budget - after 0.7999999999467491
# bits used 1284
# bit budget - after 0.5999999999467036
#  ---------
# .bits used 1282
# bit budget - after 0.39999999994665814
# bits used 1282
# bit budget - after 0.19999999994661266
#  ---------
# .bits used 1284
# bit budget - after 0.7999999999465217
#
# 	Decoding coded PAC file...
#  ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# . ---------
# .
# Done with Encode/Decode test
#
# 63.639183044433594  seconds elapsed
